# %% [markdown]
# #### importing the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('mobile_price_range_data.csv')
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
# #### checking duplicates and null if any

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %% [markdown]
# #### by examing graphs selecting which column varies the mobile price

# %%
df.plot(x='price_range',y='battery_power',kind='scatter',color='green')
plt.title('Mobile price vs battery_power')
plt.show()

# %%
df.plot(x='price_range',y='blue',kind='scatter',color='green')
plt.title('Mobile price vs blue')
plt.show()

# %%
df.plot(x='price_range',y='clock_speed',kind='scatter',color='green')
plt.title('Mobile price vs clock_speed')
plt.show()

# %%
df.plot(x='price_range',y='dual_sim',kind='scatter',color='green')
plt.title('Mobile price vs dual_sim')
plt.show()

# %%
df.plot(x='price_range',y='fc',kind='scatter',color='green')
plt.title('Mobile price vs fc')
plt.show()

# %%
df.plot(x='price_range',y='four_g',kind='scatter',color='green')
plt.title('Mobile price vs four_g')
plt.show()

# %%
df.plot(x='price_range',y='int_memory',kind='scatter',color='green')
plt.title('Mobile price vs int_memory ')
plt.show()

# %%
df.plot(x='price_range',y='m_dep',kind='scatter',color='green')
plt.title('Mobile price vs m_dep')
plt.show()

# %%
df.plot(x='price_range',y='mobile_wt',kind='scatter',color='green')
plt.title('Mobile price vs mobile_wt')
plt.show()

# %%
df.plot(x='price_range',y='ram',kind='scatter',color='green')
plt.title('Mobile price vs Ram')
plt.show()

# %%
df.plot(x='price_range',y='n_cores',kind='scatter',color='green')
plt.title('Mobile price vs n_cores')
plt.show()

# %%
df.plot(x='price_range',y='px_height',kind='scatter',color='green')
plt.title('Mobile price vs px_height')
plt.show()

# %%
df.plot(x='price_range',y='px_width',kind='scatter',color='green')
plt.title('Mobile price vs px_width')
plt.show()

# %%
df.plot(x='price_range',y='sc_h',kind='scatter',color='green')
plt.title('Mobile price vs sc_h')
plt.show()

# %%
df.plot(x='price_range',y='sc_w',kind='scatter',color='green')
plt.title('Mobile price vs sc_w')
plt.show()

# %%
df.plot(x='price_range',y='talk_time',kind='scatter',color='green')
plt.title('Mobile price vs talk_time')
plt.show()

# %%
df.plot(x='price_range',y='three_g',kind='scatter',color='green')
plt.title('Mobile price vs three_g')
plt.show()

# %%
df.plot(x='price_range',y='touch_screen',kind='scatter',color='green')
plt.title('Mobile price vs touch_screen')
plt.show()

# %%
df.plot(x='price_range',y='wifi',kind='scatter',color='green')
plt.title('Mobile price vs wifi')
plt.show()

# %% [markdown]
# after data visualization of each feature price range varies with ram feature only.

# %% [markdown]
# #### checking for outliers

# %%
df.plot(kind='box',figsize=(20,10))
plt.show()

# %% [markdown]
# #### selecting dependent and independent variable

# %%
x = df.drop('price_range',axis=1) #independent features
y = df['price_range'] #dependent features
print(type(x))
print(type(y))
print(x.shape)
print(y.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# (2000, 20)
# (2000,)

# %% [markdown]
# #### splitting the dataset into test and train data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=42)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1500, 20)
# (500, 20)
# (1500,)
# (500,)

# %% [markdown]
# #### calculation of test data shape

# %%
a = (0.25)*2000
a
# Out:
# 500.0

# %%
x_train.head()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1738            511     0          0.9         1  15       1          24
# 548             641     1          1.1         0   0       1           7
# 936             805     0          0.8         0   1       0          34
# 1389           1801     0          0.5         1   6       0          52
# 1607            744     0          1.7         1   0       1          33
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# 1738    0.6        136        3  18        367      1264  2378    18     3
# 548     0.9        192        1   3        417       759  3595     7     5
# 936     0.6         88        6   2       1262      1538  3647    18    11
# 1389    0.9        120        6  10        100      1708   258    14     8
# 1607    0.5        105        4   2       1252      1963  2700     9     3
#
#       talk_time  three_g  touch_screen  wifi
# ...

# %%
y_train.head()
# Out:
# 1738    1
# 548     2
# 936     3
# 1389    0
# 1607    2
# Name: price_range, dtype: int64

# %% [markdown]
# #### Training the model

# %%
from sklearn.preprocessing  import StandardScaler

# %%
df['wifi'].describe()
# Out:
# count    2000.000000
# mean        0.507000
# std         0.500076
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: wifi, dtype: float64

# %%
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)
x = sc.transform(x)

# %%
x_train
# Out:
# array([[-1.65171013, -0.98412598, -0.75306607, ...,  0.55887025,
#         -1.00668904, -0.99733688],
#        [-1.35739419,  1.01613007, -0.50909218, ...,  0.55887025,
#          0.99335541,  1.00267023],
#        [-0.98610331, -0.98412598, -0.87505301, ...,  0.55887025,
#         -1.00668904,  1.00267023],
#        ...,
#        [ 1.33220074,  1.01613007, -1.24101385, ...,  0.55887025,
#         -1.00668904,  1.00267023],
#        [ 1.55406969, -0.98412598, -0.75306607, ..., -1.78932408,
#          0.99335541,  1.00267023],
#        [-1.370978  ,  1.01613007, -1.1190269 , ...,  0.55887025,
#         -1.00668904, -0.99733688]])

# %%
x_test
# Out:
# array([[ 0.91789445, -0.98412598,  1.19872504, ...,  0.55887025,
#          0.99335541, -0.99733688],
#        [-0.13258707, -0.98412598, -1.24101385, ...,  0.55887025,
#         -1.00668904, -0.99733688],
#        [ 1.65594828, -0.98412598,  1.68667282, ...,  0.55887025,
#          0.99335541, -0.99733688],
#        ...,
#        [ 0.59641088, -0.98412598, -0.0211444 , ...,  0.55887025,
#         -1.00668904,  1.00267023],
#        [-0.54236542, -0.98412598,  1.56468587, ...,  0.55887025,
#          0.99335541,  1.00267023],
#        [ 0.15720094, -0.98412598, -0.14313135, ..., -1.78932408,
#         -1.00668904,  1.00267023]])

# %%
x
# Out:
# array([[-0.90233646, -0.98412598,  0.83276421, ..., -1.78932408,
#         -1.00668904,  1.00267023],
#        [-0.49708605,  1.01613007, -1.24101385, ...,  0.55887025,
#          0.99335541, -0.99733688],
#        [-1.53398375,  1.01613007, -1.24101385, ...,  0.55887025,
#          0.99335541, -0.99733688],
#        ...,
#        [ 1.51784619, -0.98412598, -0.75306607, ...,  0.55887025,
#          0.99335541, -0.99733688],
#        [ 0.61452263, -0.98412598, -0.75306607, ...,  0.55887025,
#          0.99335541,  1.00267023],
#        [-1.6539741 ,  1.01613007,  0.58879032, ...,  0.55887025,
#          0.99335541,  1.00267023]])

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
m1 = LogisticRegression()
m1.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
print('Train Score', m1.score(x_train,y_train))
print('Test Score', m1.score(x_test,y_test))
# Out:
# Train Score 0.9766666666666667
# Test Score 0.962

# %%
ypred_m1 = m1.predict(x_test)
print(ypred_m1)
# Out:
# [0 2 1 3 1 1 2 0 3 1 0 1 2 3 3 2 3 3 1 0 0 2 1 2 0 1 3 2 2 0 0 0 3 0 1 1 2
#  0 3 0 2 3 2 0 2 2 2 1 3 1 3 1 0 0 1 0 1 3 0 0 1 3 3 1 0 0 3 3 1 2 2 2 0 1
#  2 0 1 3 2 2 3 2 1 0 1 3 1 3 3 0 3 3 2 1 3 2 2 3 1 1 0 0 1 0 0 3 2 0 1 1 0
#  0 3 1 3 2 3 2 0 2 1 3 2 1 3 3 0 2 0 2 3 0 2 2 0 3 1 0 0 2 3 1 3 2 0 0 0 1
#  1 2 3 1 1 0 2 2 0 1 0 1 2 3 3 3 1 0 1 2 2 3 3 0 1 0 3 1 1 2 1 0 0 0 0 0 3
#  2 0 3 0 0 0 0 1 3 3 1 0 1 1 1 1 2 2 3 3 3 1 2 0 0 0 2 1 1 3 1 1 2 1 1 3 2
#  3 0 0 2 1 3 0 1 2 0 2 3 2 0 1 3 3 0 1 3 3 3 0 3 1 2 3 3 2 1 0 3 3 1 3 3 3
#  3 3 0 1 2 2 2 3 0 2 3 2 2 2 1 0 2 0 3 3 1 3 1 0 3 1 2 0 0 3 0 1 2 3 3 3 1
#  1 0 1 3 3 0 1 2 2 0 3 3 2 3 2 3 2 0 2 1 1 1 0 0 0 3 3 3 1 0 1 0 1 2 3 0 3
#  3 2 1 3 0 0 3 1 3 2 0 1 1 1 1 1 3 1 0 0 3 3 0 3 0 0 2 0 1 2 2 2 3 0 3 2 3
#  3 3 3 2 1 1 0 3 1 3 3 0 2 3 2 3 3 3 0 0 2 3 0 0 2 3 2 1 1 2 1 3 1 3 1 2 0
#  0 1 0 1 0 1 0 2 2 3 2 1 1 2 1 1 3 1 0 0 3 0 1 0 1 2 2 3 0 2 0 1 1 3 3 0 2
# ...

# %%
from sklearn.metrics import accuracy_score,confusion_matrix, classification_report

# %%
def eval_model(ytest ,ypred):
    cm = confusion_matrix(y_test,ypred_m1)
    print(cm)
    print(classification_report(y_test,ypred_m1))
    
def mscore(model):
    print('Train Score', model.score(x_train,y_train))
    print('Test Score', model.score(x_test,y_test))

# %%
mscore(m1)
eval_model(y_test,ypred_m1)
# Out:
# Train Score 0.9766666666666667
# Test Score 0.962
# [[127   5   0   0]
#  [  2 116   0   0]
#  [  0   5 109   6]
#  [  0   0   1 129]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97       132
#            1       0.92      0.98      0.95       118
#            2       0.99      0.91      0.95       120
#            3       0.96      0.99      0.97       130
#
#     accuracy                           0.96       500
#    macro avg       0.96      0.96      0.96       500
# weighted avg       0.96      0.96      0.96       500

# %%
lr_acc = accuracy_score(ypred_m1,y_test)
lr_acc
# Out:
# 0.962

# %%
print(confusion_matrix(ypred_m1,y_test))
print(classification_report(y_test,ypred_m1))
# Out:
# [[127   2   0   0]
#  [  5 116   5   0]
#  [  0   0 109   1]
#  [  0   0   6 129]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97       132
#            1       0.92      0.98      0.95       118
#            2       0.99      0.91      0.95       120
#            3       0.96      0.99      0.97       130
#
#     accuracy                           0.96       500
#    macro avg       0.96      0.96      0.96       500
# weighted avg       0.96      0.96      0.96       500

# %% [markdown]
# ### KNN algorithm

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
m2 = KNeighborsClassifier(n_neighbors=11)
m2.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=11)

# %%
print('Train Score',m2.score(x_train,y_train))
print('Test Score',m2.score(x_test,y_test))
# Out:
# Train Score 0.6746666666666666
# Test Score 0.542

# %%
ypred_m2 = m2.predict(x_test)
print(ypred_m2)
# Out:
# [0 0 0 2 1 1 1 0 3 1 1 0 1 3 2 2 3 3 0 0 0 1 0 1 0 1 2 1 1 0 0 0 3 0 3 1 2
#  0 3 3 2 3 3 0 2 0 1 2 3 0 3 0 1 0 1 2 3 3 0 1 0 2 2 2 0 0 3 3 2 1 0 1 0 2
#  2 0 1 3 2 2 3 0 1 1 0 3 0 2 2 0 3 3 3 1 3 1 2 3 0 3 0 1 2 1 0 3 2 0 0 1 0
#  0 2 1 1 2 3 2 0 2 0 1 3 1 3 2 0 2 1 3 2 0 1 2 0 3 1 1 1 1 1 0 3 1 1 0 1 0
#  3 0 3 0 1 0 2 2 0 2 0 0 1 3 3 3 1 0 0 2 2 3 2 1 0 0 3 0 0 3 0 1 0 0 0 0 3
#  3 1 2 0 1 1 1 1 2 3 2 0 0 2 0 1 1 1 3 2 2 0 2 0 2 0 3 1 2 1 0 0 2 1 1 2 1
#  2 0 0 2 0 3 0 0 2 0 3 3 2 0 0 3 2 0 2 2 2 3 0 2 1 3 3 3 3 1 1 3 3 2 3 2 2
#  3 2 1 2 2 1 0 2 0 1 3 2 1 2 2 0 1 0 1 3 1 2 1 0 3 1 3 0 0 2 0 2 1 3 2 2 1
#  0 1 0 3 2 0 2 1 2 0 2 3 1 3 2 3 1 0 3 0 3 2 0 0 0 3 2 3 1 0 2 1 1 1 3 0 2
#  1 1 0 3 0 0 1 1 3 2 0 0 0 1 1 1 3 2 0 0 3 2 0 1 0 0 1 0 0 1 1 2 3 0 3 2 2
#  3 3 2 3 2 2 0 3 1 2 3 2 2 3 2 2 3 3 0 1 0 3 0 0 2 3 1 1 0 2 1 2 0 2 1 2 0
#  0 1 0 1 0 1 1 1 3 2 2 1 1 3 1 0 3 0 0 0 3 0 3 1 1 2 1 2 0 2 1 1 1 3 2 0 2
# ...

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
def eval_model(ytest ,ypred):
    cm = confusion_matrix(y_test,ypred_m2)
    print(cm)
    print(classification_report(y_test,ypred_m2))
    
def mscore(model):
    print('Train Score', model.score(x_train,y_train))
    print('Test Score', model.score(x_test,y_test))

# %%
mscore(m2)
eval_model(y_test,ypred_m2)
# Out:
# Train Score 0.6746666666666666
# Test Score 0.542
# [[98 29  4  1]
#  [43 47 22  6]
#  [ 9 42 51 18]
#  [ 1  7 47 75]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.74      0.69       132
#            1       0.38      0.40      0.39       118
#            2       0.41      0.42      0.42       120
#            3       0.75      0.58      0.65       130
#
#     accuracy                           0.54       500
#    macro avg       0.55      0.54      0.54       500
# weighted avg       0.55      0.54      0.54       500

# %%
knn_acc = accuracy_score(y_test,ypred_m2)
knn_acc
# Out:
# 0.542

# %%
cm = confusion_matrix(y_test,ypred_m2)
print(cm)
print(classification_report(y_test,ypred_m2))
# Out:
# [[98 29  4  1]
#  [43 47 22  6]
#  [ 9 42 51 18]
#  [ 1  7 47 75]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.74      0.69       132
#            1       0.38      0.40      0.39       118
#            2       0.41      0.42      0.42       120
#            3       0.75      0.58      0.65       130
#
#     accuracy                           0.54       500
#    macro avg       0.55      0.54      0.54       500
# weighted avg       0.55      0.54      0.54       500

# %% [markdown]
# ### Decision Tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
m3 = DecisionTreeClassifier(criterion='entropy')
m3.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
print('Train Score',m3.score(x_train,y_train))
print('Test Score',m3.score(x_test,y_test))
# Out:
# Train Score 1.0
# Test Score 0.85

# %%
ypred_m3 = m3.predict(x_test)
print(ypred_m3)
# Out:
# [0 2 1 3 1 1 1 0 2 1 0 1 2 3 2 2 3 3 1 0 0 1 1 2 0 1 3 2 2 0 0 0 3 0 1 1 2
#  0 3 0 2 3 2 0 2 3 1 0 3 1 3 1 0 0 1 1 1 2 0 0 0 3 3 1 0 0 3 3 1 2 1 2 0 1
#  3 0 1 3 2 1 3 2 1 0 2 3 2 3 3 0 2 3 2 1 3 2 2 3 2 1 0 0 1 0 0 3 3 0 1 1 0
#  0 3 1 2 2 3 2 0 2 1 3 2 1 3 3 0 2 0 2 3 0 2 2 0 2 1 0 0 2 3 0 3 2 0 0 0 1
#  2 3 3 2 1 0 2 2 0 1 0 2 2 2 2 2 1 0 1 2 2 3 3 1 1 1 3 1 2 2 1 1 0 0 0 0 3
#  2 0 3 0 0 0 0 1 3 2 1 0 1 2 0 1 2 2 2 3 3 1 2 0 0 0 2 1 1 3 1 0 2 1 1 3 2
#  3 0 0 2 1 3 0 0 2 0 2 3 2 1 1 3 3 0 1 3 3 3 0 3 1 2 3 3 3 1 1 3 3 1 3 3 3
#  3 3 0 1 1 3 1 3 0 1 3 2 2 2 1 0 1 0 2 3 1 3 1 0 3 1 2 0 0 3 0 1 2 3 3 3 1
#  0 0 1 3 3 0 1 2 2 0 3 3 3 3 2 3 2 0 2 1 1 1 0 0 0 3 2 3 1 0 1 0 3 3 3 1 2
#  3 2 1 3 0 0 2 1 3 2 0 1 1 1 0 1 3 1 0 0 3 3 0 3 0 0 2 0 1 2 2 2 3 0 3 2 2
#  3 3 3 3 1 1 0 3 1 3 3 0 2 3 2 3 3 3 1 0 2 3 0 0 2 3 1 1 1 2 1 3 1 3 1 2 0
#  1 1 0 1 0 2 0 2 2 3 2 1 1 2 1 0 3 1 0 0 3 0 1 0 0 2 3 3 0 2 0 1 1 3 3 0 3
# ...

# %%
from sklearn.metrics import accuracy_score,confusion_matrix, classification_report

# %%
def eval_model(ytest ,ypred):
    cm = confusion_matrix(y_test,ypred_m3)
    print(cm)
    print(classification_report(y_test,ypred_m3))
    
def mscore(model):
    print('Train Score', model.score(x_train,y_train))
    print('Test Score', model.score(x_test,y_test))

# %%
mscore(m3)
eval_model(y_test,ypred_m3)
# Out:
# Train Score 1.0
# Test Score 0.85
# [[120  12   0   0]
#  [ 12  98   8   0]
#  [  0  13  91  16]
#  [  0   0  14 116]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91       132
#            1       0.80      0.83      0.81       118
#            2       0.81      0.76      0.78       120
#            3       0.88      0.89      0.89       130
#
#     accuracy                           0.85       500
#    macro avg       0.85      0.85      0.85       500
# weighted avg       0.85      0.85      0.85       500

# %%
dtc_acc = accuracy_score(ypred_m3,y_test)
dtc_acc
# Out:
# 0.85

# %%
print(confusion_matrix(ypred_m3,y_test))
# Out:
# [[120  12   0   0]
#  [ 12  98  13   0]
#  [  0   8  91  14]
#  [  0   0  16 116]]

# %%
print(classification_report(y_test,ypred_m3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91       132
#            1       0.80      0.83      0.81       118
#            2       0.81      0.76      0.78       120
#            3       0.88      0.89      0.89       130
#
#     accuracy                           0.85       500
#    macro avg       0.85      0.85      0.85       500
# weighted avg       0.85      0.85      0.85       500

# %% [markdown]
# #### Random Forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
m4 = RandomForestClassifier(n_estimators=70,criterion='entropy',max_depth=6,random_state=42)
m4.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=6, n_estimators=70,
#                        random_state=42)

# %%
print('Train Score',m4.score(x_train,y_train))
print('Test Score',m4.score(x_test,y_test))
# Out:
# Train Score 0.942
# Test Score 0.832

# %%
def eval_model(ytest ,ypred):
    cm = confusion_matrix(y_test,ypred_m4)
    print(cm)
    print(classification_report(y_test,ypred_m4))
    
def mscore(model):
    print('Train Score', model.score(x_train,y_train))
    print('Test Score', model.score(x_test,y_test))

# %%
mscore(m4)
# Out:
# Train Score 0.942
# Test Score 0.832

# %%
ypred_m4 = m4.predict(x_test)
print(ypred_m4)
# Out:
# [0 2 1 3 1 2 2 0 3 1 0 1 2 3 3 2 3 3 1 0 0 1 1 1 0 1 2 2 2 0 0 0 3 0 1 1 3
#  0 3 0 2 3 2 0 3 3 2 1 3 1 3 1 0 0 0 0 1 3 0 0 0 3 3 2 0 0 3 3 1 2 2 3 0 1
#  3 0 0 3 2 2 3 2 1 0 1 3 2 3 3 0 3 3 2 1 3 2 2 3 2 1 0 0 1 0 0 3 2 0 1 1 0
#  0 3 1 2 2 3 2 0 2 1 3 2 1 3 3 0 3 0 2 3 0 2 2 0 3 1 0 0 2 3 0 2 2 0 0 0 1
#  2 2 3 1 1 0 2 2 0 1 0 2 2 3 3 3 1 0 0 2 1 3 3 1 0 0 3 1 1 2 1 0 0 0 0 0 3
#  2 0 3 0 1 0 0 1 3 3 1 0 1 2 1 1 2 1 2 2 3 1 2 0 0 0 1 1 1 3 1 0 2 2 1 3 1
#  3 0 0 2 1 2 0 0 1 0 1 3 2 1 1 3 3 0 2 3 3 3 0 3 1 2 3 3 3 1 1 3 3 1 3 3 3
#  3 3 0 1 2 2 2 2 0 2 3 2 3 2 1 0 2 0 3 3 1 3 1 0 3 1 2 0 0 3 0 1 2 3 3 3 1
#  0 0 1 3 3 0 1 1 2 0 3 3 2 3 1 3 2 0 2 1 2 1 0 0 1 3 3 3 1 0 1 0 2 2 2 0 3
#  3 2 1 2 0 0 3 1 3 2 0 1 1 2 0 1 3 1 0 0 3 3 0 3 0 0 1 0 0 2 2 2 3 0 3 2 2
#  3 3 3 2 1 2 0 3 2 3 3 0 1 3 2 3 3 3 0 0 2 3 0 0 2 3 1 1 1 2 1 3 0 3 1 2 0
#  0 1 0 1 0 2 1 1 3 3 2 1 1 3 1 0 3 1 0 0 3 0 1 1 1 1 3 3 0 2 1 1 1 3 3 0 2
# ...

# %%
eval_model(y_test,ypred_m4)
# Out:
# [[121  11   0   0]
#  [ 14  91  13   0]
#  [  0  20  84  16]
#  [  0   0  10 120]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91       132
#            1       0.75      0.77      0.76       118
#            2       0.79      0.70      0.74       120
#            3       0.88      0.92      0.90       130
#
#     accuracy                           0.83       500
#    macro avg       0.83      0.83      0.83       500
# weighted avg       0.83      0.83      0.83       500

# %%
rfc_acc = accuracy_score(ypred_m4,y_test)
rfc_acc
# Out:
# 0.832

# %% [markdown]
# #### SVM classifier with linear kernel

# %%
from sklearn.svm import SVC

# %%
m5 = SVC(kernel='linear',C=0.01)
m5.fit(x_train,y_train)
# Out:
# SVC(C=0.01, kernel='linear')

# %%
def eval_model(ytest ,ypred):
    cm = confusion_matrix(y_test,ypred_m5)
    print(cm)
    print(classification_report(y_test,ypred_m5))
    
def mscore(model):
    print('Train Score', model.score(x_train,y_train))
    print('Test Score', model.score(x_test,y_test))

# %%
mscore(m5)
# Out:
# Train Score 0.9266666666666666
# Test Score 0.908

# %%
ypred_m5 = m5.predict(x_test)
print(ypred_m5)
# Out:
# [0 2 1 3 1 1 2 0 3 1 0 1 1 3 3 2 3 3 1 0 0 1 1 2 0 1 3 2 2 0 0 0 3 0 2 1 2
#  0 3 0 2 3 2 0 2 2 1 1 3 1 3 1 0 0 1 0 1 3 0 0 1 3 3 1 0 0 3 3 1 2 2 2 0 1
#  2 0 1 3 2 2 3 1 1 0 1 3 1 3 3 0 3 3 2 1 3 2 2 3 2 1 0 0 1 0 1 3 2 0 1 1 0
#  0 3 1 3 2 3 2 0 2 1 3 2 2 3 3 0 2 0 2 3 0 2 2 0 2 1 0 0 2 3 1 3 2 0 0 0 1
#  1 2 3 1 1 0 2 2 0 2 0 2 2 3 3 2 1 0 1 2 2 2 2 0 1 0 3 1 1 2 1 0 0 0 0 0 3
#  2 0 2 0 0 0 0 1 3 3 1 0 1 2 1 1 2 2 2 3 3 1 2 0 0 0 2 1 1 3 1 1 2 1 1 3 1
#  3 0 0 2 1 3 0 1 1 0 2 3 2 0 1 2 3 0 1 3 2 3 0 3 1 2 3 3 2 1 0 3 3 1 3 3 3
#  3 3 0 1 2 2 2 2 0 2 3 2 2 2 1 0 2 0 2 3 1 3 1 0 3 1 2 0 0 3 0 1 2 3 3 3 1
#  1 0 1 3 3 0 1 2 2 0 3 3 2 3 1 3 2 0 2 1 1 1 0 0 0 2 3 3 1 0 1 1 1 2 2 0 2
#  3 2 1 3 0 0 3 1 3 2 0 1 1 1 1 1 3 1 0 0 2 3 0 3 0 0 2 0 1 2 2 2 3 0 3 2 3
#  3 3 3 2 1 1 0 3 1 3 3 0 2 3 2 3 3 3 0 0 2 3 0 0 2 3 2 1 1 2 1 3 1 2 1 2 0
#  0 1 0 1 0 2 0 2 2 3 2 1 1 2 1 1 3 1 0 0 3 0 2 0 1 2 2 3 0 2 0 1 1 3 3 0 2
# ...

# %%
eval_model(y_test,ypred_m5)
# Out:
# [[124   8   0   0]
#  [  3 108   7   0]
#  [  0  11 106   3]
#  [  0   0  14 116]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96       132
#            1       0.85      0.92      0.88       118
#            2       0.83      0.88      0.86       120
#            3       0.97      0.89      0.93       130
#
#     accuracy                           0.91       500
#    macro avg       0.91      0.91      0.91       500
# weighted avg       0.91      0.91      0.91       500

# %%
svm_linear_acc = accuracy_score(ypred_m5,y_test)
svm_linear_acc
# Out:
# 0.908

# %% [markdown]
# #### SVM classifier with rbf kernel

# %%
from sklearn.svm import SVC

# %%
m6 = SVC(kernel='rbf',C=1,gamma=0.1)
m6.fit(x_train,y_train)
# Out:
# SVC(C=1, gamma=0.1)

# %%
def eval_model(ytest ,ypred):
    cm = confusion_matrix(y_test,ypred_m6)
    print(cm)
    print(classification_report(y_test,ypred_m6))
    
def mscore(model):
    print('Train Score', model.score(x_train,y_train))
    print('Test Score', model.score(x_test,y_test))

# %%
mscore(m6)
# Out:
# Train Score 0.998
# Test Score 0.82

# %%
ypred_m6 = m6.predict(x_test)
print(ypred_m6)
# Out:
# [0 1 1 3 1 1 1 0 3 1 0 1 1 3 2 2 3 3 1 0 0 2 0 2 0 1 2 2 2 0 0 0 3 0 2 1 2
#  0 3 0 2 3 2 0 2 3 1 1 3 1 3 1 0 0 1 0 1 3 0 0 1 3 3 1 0 0 3 3 2 2 1 3 0 1
#  2 0 1 3 2 2 3 2 1 0 1 3 1 3 3 0 3 3 2 1 3 2 2 3 1 1 0 0 2 1 0 3 2 0 1 1 0
#  0 2 1 3 2 3 2 0 2 0 3 3 1 3 3 0 3 1 2 3 0 2 2 0 3 1 0 1 2 3 1 3 2 0 0 1 1
#  2 2 3 1 1 0 2 2 0 1 0 1 2 3 3 3 1 0 0 2 2 3 2 1 1 0 3 1 2 2 1 0 0 0 0 0 3
#  2 0 2 0 0 0 0 1 3 3 2 0 1 2 0 1 1 2 3 2 3 1 2 0 0 0 2 2 1 3 1 0 2 2 1 3 1
#  2 0 0 2 0 2 0 1 2 0 1 3 2 0 1 3 3 0 2 3 2 3 0 3 1 2 3 3 3 1 1 3 3 1 3 3 3
#  3 3 1 2 2 2 2 3 0 1 3 2 2 2 1 0 1 0 2 3 1 3 1 1 3 1 2 0 0 3 0 1 1 3 2 3 1
#  1 0 1 3 3 0 1 2 2 0 3 3 2 3 1 3 2 0 2 1 1 1 0 0 1 3 2 3 1 0 2 0 1 2 2 0 3
#  2 2 1 3 0 0 3 1 3 2 0 1 1 2 1 1 3 1 0 1 3 3 0 3 0 0 1 0 0 1 2 2 3 0 2 2 3
#  3 3 3 2 1 2 0 3 1 3 3 0 2 3 2 3 3 3 0 0 2 3 0 0 2 3 2 1 1 2 1 2 1 2 1 2 0
#  0 1 0 1 0 2 0 2 3 3 2 1 1 3 1 0 3 1 0 0 3 0 2 1 1 1 2 3 0 2 1 1 1 2 3 0 2
# ...

# %%
eval_model(y_test,ypred_m6)
# Out:
# [[116  16   0   0]
#  [ 10  92  16   0]
#  [  0  23  88   9]
#  [  0   0  16 114]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.88      0.90       132
#            1       0.70      0.78      0.74       118
#            2       0.73      0.73      0.73       120
#            3       0.93      0.88      0.90       130
#
#     accuracy                           0.82       500
#    macro avg       0.82      0.82      0.82       500
# weighted avg       0.83      0.82      0.82       500

# %%
svm_rbf_acc = accuracy_score(ypred_m6,y_test)
svm_rbf_acc
# Out:
# 0.82

# %% [markdown]
# #### `predicting the price range

# %%
plt.bar(x=['LR','KNN','DTC','RFC','SVM_Linear','SVM_rbf'],height= [lr_acc,knn_acc,dtc_acc,rfc_acc,svm_linear_acc,svm_rbf_acc],color='black')
plt.title('Accuracy of different Algos')
plt.xlabel('Algorithms')
plt.ylabel('Accuracy Score')
plt.show()

# %% [markdown]
# #### Best accuracy model

# %%
accuracies = [lr_acc,knn_acc,dtc_acc,rfc_acc,svm_linear_acc,svm_rbf_acc]
model_names = ['Logistic Regression', 'KNN Classification', 'Decision Tree Classifier', 'RandomForest Classifier','SVM Linear Kernel','SVM rbf Kernel']

# index of the model with the highest accuracy
best_model_index = accuracies.index(max(accuracies))

# name of the best model
best_model_name = model_names[best_model_index]
print("The best model is", best_model_name, "with an accuracy of", accuracies[best_model_index])
# Out:
# The best model is Logistic Regression with an accuracy of 0.962
